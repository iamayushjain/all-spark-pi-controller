# %%
import import_ipynb
from keyboard_triggers import *
# Out:
# importing Jupyter notebook from keyboard_triggers.ipynb

# %%
demo_keyboard_listener()
# Out:
# {'f': '0', 'b': '0', 'l': 0, 'r': 1}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 1, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': 'm', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': 'l', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': 'l', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': 'l', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': 'l', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 1, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 1, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 1, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': 'm', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': 'm', 'l': 0, 'r': 0}
# {'f': '0', 'b': '0', 'l': 0, 'r': 0}
# {'f': '0', 'b': 'm', 'l': 0, 'r': 0}
# ...
